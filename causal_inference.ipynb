# %%
library(dplyr)
library(purrr)
library(stringr)

library(cem)
library(MatchIt)
library(lmtest)
library(sandwich)
library(cobalt)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: tcltk
#
# Warning message:
# “no DISPLAY variable so Tk is not available”
# Loading required package: lattice
#
#
# How to use CEM? Type vignette("cem")
#
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#  cobalt (Version 4.4.0, Build Date: 2022-08-13)
#
#
# Attaching package: ‘cobalt’
#
#
# The following object is masked from ‘package:MatchIt’:
#
#     lalonde

# %%
str_prod = function(x1, x2){
    out = c()
    for(elem1 in x1){
        for(elem2 in x2){
            out = append(out, paste0(elem1, elem2))
        }
    }
    return(out)
}

# %%
# Global Variables

location_category = c("HOME","WORK","OTHERS")
time_category = "TOD"

activity_category= "SEDENTARY"
dut_prefix = "DUT_"

app_category = c("ENTER","HEALTH","INFO","SOCIAL","SYSTEM","WORK")

# Feacture Extracted from each catergorical app usage
# UT: Usage Time, LC: Launch Count
app_prefixes = c("LC_", "UT_") 
app_usage = str_prod(app_prefixes, app_category)
all_app_usage = str_prod(app_prefixes,c('ALL'))

all_app_usage
app_usage
# Out:
# [1] "LC_ALL" "UT_ALL"
#  [1] "LC_ENTER"  "LC_HEALTH" "LC_INFO"   "LC_SOCIAL" "LC_SYSTEM" "LC_WORK"
#  [7] "UT_ENTER"  "UT_HEALTH" "UT_INFO"   "UT_SOCIAL" "UT_SYSTEM" "UT_WORK"

# %%
# file_name: file of raw data
# isCategory: Category or All
prepareData = function(df, isCategory){

    # Extract TOD
    time = str_split_fixed(df$READABLE_START, " ", 2)[,2]
    hour = as.numeric(str_split_fixed(time, ":", 2)[,1])
    df[time_category] = as.integer(hour/6)    
    
    # Construct Variable List used for Causal Inference
    variable_list = if(isCategory) app_usage else all_app_usage
    variable_list = append(variable_list, paste0(dut_prefix,location_category))
    variable_list = append(variable_list, paste0(dut_prefix,activity_category))
    variable_list = append(variable_list, time_category)
    df = df[,variable_list]

    # Remove TOD with 0
    df = df[df[time_category] != 0,]
    rownames(df) = NULL 
    df[,time_category] = as.factor(df[,time_category])

    # Min-Max Normalization
    df = as.data.frame(sapply(df, function(x){return(if(is.numeric(x)) (x-min(x))/(max(x)-min(x)) else x)}))
    # Remove NaN
    removed = colnames(df[,colSums(is.na(df)) != 0])
    df = df[,colSums(is.na(df)) == 0]

    out = list()
    out$df = df
    out$removed_col = removed

    return(out)
}

df=read.csv("Data/15Min/P1.csv")
out = prepareData(df, TRUE)
df_processed = out$df

summary(df_processed)
# Out:
#     LC_ENTER          LC_INFO          LC_SOCIAL         LC_SYSTEM
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.03448
#  Mean   :0.01762   Mean   :0.01202   Mean   :0.06954   Mean   :0.11796
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.08929   3rd Qu.:0.17241
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#     LC_WORK           UT_ENTER          UT_INFO          UT_SOCIAL
#  Min.   :0.00000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.00000   Median :0.00000   Median :0.00000   Median :0.00000
#  Mean   :0.01029   Mean   :0.02646   Mean   :0.01738   Mean   :0.09884
#  3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.00000   3rd Qu.:0.09941
#  Max.   :1.00000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#    UT_SYSTEM           UT_WORK           DUT_HOME         DUT_WORK
#  Min.   :0.000000   Min.   :0.00000   Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.000000   1st Qu.:0.00000   1st Qu.:0.0000   1st Qu.:0.0000
#  Median :0.002882   Median :0.00000   Median :0.0000   Median :0.0000
#  Mean   :0.057570   Mean   :0.01879   Mean   :0.3783   Mean   :0.2784
#  3rd Qu.:0.055057   3rd Qu.:0.00000   3rd Qu.:1.0000   3rd Qu.:0.9398
#  Max.   :1.000000   Max.   :1.00000   Max.   :1.0000   Max.   :1.0000
#    DUT_OTHERS     DUT_SEDENTARY         TOD
#  Min.   :0.0000   Min.   :0.0000   Min.   :1.000
#  1st Qu.:0.0000   1st Qu.:1.0000   1st Qu.:1.000
#  Median :0.0000   Median :1.0000   Median :2.000
#  Mean   :0.2254   Mean   :0.9245   Mean   :2.049
#  3rd Qu.:0.2342   3rd Qu.:1.0000   3rd Qu.:3.000
#  Max.   :1.0000   Max.   :1.0000   Max.   :3.000

# %%
# Investigate the covariates based on the correlation with the outcome
# Calculate and return sig, nonsig list
sigCorr = function(df, outcome_variable){
    df = df[, sapply(df, is.numeric)]

    test = function (col1, col2){
        stat = cor.test(df[,col1], df[,col2], method = "kendall")
        return(stat$p.value < .05 && abs(stat$estimate['tau']) > .2)
    }
    sig_corr = c()
    for(col in colnames(df)){
        if(col != outcome_variable){
            if(test(outcome_variable, col)) sig_corr =append(sig_corr, col)
        } 
    }
    return(sig_corr)
}

df=read.csv("Data/15Min/P1.csv")
out = prepareData(df, TRUE)
df_processed = out$df

sigCorr(df_processed, "DUT_SEDENTARY")
# Out:
# [1] "LC_INFO"   "LC_SOCIAL" "LC_SYSTEM" "UT_INFO"   "UT_SOCIAL" "UT_SYSTEM"
# [7] "DUT_HOME"

# %%
# Matching Process 
# formula: string as formula
# distance: ["PS", "Mahalanobis", "CEM"]
# method: ["nearest","full"] for "PS" and Mahalanobis

causal_inference = function(df, formula, outcome, distance, method = NULL, n_cutpoint_sampling = 10){
    formula = as.formula(formula)
    treat_variable = all.vars(formula)[1]
    confoundings = all.vars(formula)[-1]
    if(distance == "PS" || distance == "Mahalanobis"){
        m.out = matchit(formula, 
                        data= df,
                        method = if(distance == "PS") method else "nearest",
                        distance = if(distance == "PS") "glm" else "mahalanobis")
        m.balance = summary(m.out, un = FALSE)
        m.max_smd = max(abs(m.balance$sum.matched[-1,"Std. Mean Diff."]))
        m.treated = m.balance$nn["Matched","Treated"]
        m.data = match.data(m.out)
        m.att = NULL
        tryCatch({
            fit = lm(as.formula(paste(outcome, "~", treat_variable)), 
                data = m.data,
                weights = m.data$weights)
            m.att  = coeftest(fit, vcov. = vcovCL, cluster = m.data$subclass)
        }, error = function(e){
            stopifnot(m.balance$nn["Matched","Treated"] <= 1 || m.balance$nn["Matched","Control"] <= 1)
            # Error if treated or matched object exist for only once
            # print(e)
            # print(m.balance$nn)
            # print(formula)
        })

        
        out = list()
        out$m.out = m.out
        out$m.balance = m.balance
        out$m.max_smd = m.max_smd
        out$m.treated = m.treated
        out$m.att = m.att
        return(out)
    }else if(distance == "CEM"){
        drops = match(all.vars(formula), colnames(df))
        drops = colnames(df)[-drops]

        best.space = NULL
        best.treated = -1
        n_error = 0 
        best.bal.out = NULL

        for(i in 1:(n_cutpoint_sampling/10)){
            tryCatch({
                space = cemspace(treatment = treat_variable,
                        data = df,
                        drop = drops,
                        R = 10,
                        plot = FALSE,
                        minimal = 1,
                        maximal = 15)
                for(i in 1:10){
                    cem.out = cem(treat_variable, data = df, drop = drops, cutpoints =space$coars[[i]])
                    bal.out = bal.tab(cem.out, data = df, un = TRUE, stats= "m")
                    if(max(abs(bal.out$Balance$Diff.Adj))< .25 &&
                        cem.out$tab["Matched","G1"] > best.treated){
                        best.treated = cem.out$tab["Matched","G1"]
                        best.space = space$coars[[i]]
                    }
                }
            }, error = function(e){
                n_error = n_error + 1
            })
        }
        if(best.treated == -1){
            out = list()
            out$n_error = n_error
            return(out)
        }


        m.out = cem(treat_variable, data = df, drop = drops, cutpoints = best.space)
        m.balance = bal.tab(cem.out, data = df, un = TRUE, stats= "m")
        m.att = att(cem.out, as.formula(paste(outcome, treat_variable, sep= " ~ ")), data = df)

        out = list()
        out$m.out = m.out
        out$m.balance = m.balance
        out$m.att = m.att
        out$m.treated = best.treated
        out$n_error = n_error
        return(out)
    }else{
        stop("Undefined Distance")
    }
    # Assessing the balance
    
}
treatment = "UT_WORK"
outcome_variable = "DUT_SEDENTARY"

df = read.csv("Data/15Min/P2.csv")
out=prepareData(df, TRUE)
print(paste(out$removed, collapse = " "))
df = out$df

correlates = sigCorr(df, "DUT_SEDENTARY")
print(paste(correlates, collapse = " "))
variables = append(outcome_variable, correlates)
df = df[,variables]
idx = match(treatment, correlates)
if(!is.na(idx)){
    confoundings = correlates[-idx]
    df$treat = ifelse(df[,treatment]>mean(df[,treatment]), 1, 0)
    print(causal_inference(df,formula = paste("treat ~ ", paste(confoundings, collapse= " + "), sep = ""), 
                    outcome = outcome_variable, distance = "PS",method = "nearest"))
    print(causal_inference(df,formula = paste("treat ~ ", paste(confoundings, collapse= " + "), sep = ""), 
                    outcome = outcome_variable, distance = "PS",method = "full"))   
                                     
    print(causal_inference(df,formula = paste("treat ~ ", paste(confoundings, collapse= " + "), sep = ""), 
                    outcome = outcome_variable, distance = "Mahalanobis",method = "nearest"))

    print(causal_inference(df,formula = paste("treat ~ ", paste(confoundings, collapse= " + "), sep = ""), 
                    outcome = outcome_variable, distance = "CEM"))
}else{
    print("Treatment is not correlated with variables")
}
# Out:
# [1] "LC_HEALTH UT_HEALTH"
# [1] "LC_SOCIAL LC_SYSTEM LC_WORK UT_SOCIAL UT_SYSTEM UT_WORK DUT_HOME"
# $m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 390 (original), 46 (matched)
#  - target estimand: ATT
#  - covariates: LC_SOCIAL, LC_SYSTEM, LC_WORK, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.7149        0.2058          1.4136     2.1186    0.0541
# LC_SOCIAL        0.2151        0.3501         -1.0235     0.2444    0.1465
# LC_SYSTEM        0.3215        0.3860         -0.2807     0.8380    0.0819
# LC_WORK          0.3120        0.0563          0.9300    17.8387    0.2870
# UT_SOCIAL        0.2134        0.2728         -0.2308     1.5125    0.1097
# UT_SYSTEM        0.0749        0.0908         -0.1370     1.1817    0.0658
# DUT_HOME         0.2152        0.2125          0.0071     1.2638    0.0567
#           eCDF Max Std. Pair Dist.
# distance    0.6522          1.4136
# LC_SOCIAL   0.3043          1.9234
# LC_SYSTEM   0.2609          0.8420
# LC_WORK     0.5652          0.9300
# UT_SOCIAL   0.3478          0.9683
# UT_SYSTEM   0.1739          0.7314
# DUT_HOME    0.0870          0.8751
#
# Sample Sizes:
#           Control Treated
# All           367      23
# Matched        23      23
# Unmatched     344       0
# Discarded       0       0
#
#
# $m.max_smd
# [1] 1.023545
#
# $m.treated
# [1] 23
#
# $m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.614971   0.063131  9.7412 1.49e-12 ***
# treat       0.132547   0.092206  1.4375   0.1576
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
# $m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 390 (original), 390 (matched)
#  - target estimand: ATT
#  - covariates: LC_SOCIAL, LC_SYSTEM, LC_WORK, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.7149        0.7066          0.0229     0.6945    0.0314
# LC_SOCIAL        0.2151        0.1737          0.3140     0.5357    0.1216
# LC_SYSTEM        0.3215        0.2631          0.2537     1.0262    0.1227
# LC_WORK          0.3120        0.1694          0.5187     6.6143    0.1294
# UT_SOCIAL        0.2134        0.1491          0.2500     1.6248    0.0958
# UT_SYSTEM        0.0749        0.0739          0.0084     1.7994    0.1208
# DUT_HOME         0.2152        0.2712         -0.1437     1.8843    0.2340
#           eCDF Max Std. Pair Dist.
# distance    0.3913          0.1331
# LC_SOCIAL   0.4339          0.8070
# LC_SYSTEM   0.3643          1.0668
# LC_WORK     0.3478          0.2296
# UT_SOCIAL   0.3177          0.3658
# UT_SYSTEM   0.4830          1.6402
# DUT_HOME    0.3926          0.7137
#
# Sample Sizes:
#               Control Treated
# All            367.        23
# Matched (ESS)    2.93      23
# Matched        367.        23
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $m.max_smd
# [1] 0.5186579
#
# $m.treated
# [1] 23
#
# $m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.712769   0.058393 12.2064   <2e-16 ***
# treat       0.034750   0.064750  0.5367   0.5918
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
# $m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 390 (original), 46 (matched)
#  - target estimand: ATT
#  - covariates: LC_SOCIAL, LC_SYSTEM, LC_WORK, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_SOCIAL        0.2151        0.1649          0.3813     1.6587    0.0894
# LC_SYSTEM        0.3215        0.2372          0.3666     1.0766    0.1003
# LC_WORK          0.3120        0.0614          0.9114    19.2683    0.2783
# UT_SOCIAL        0.2134        0.1700          0.1687     1.2937    0.0783
# UT_SYSTEM        0.0749        0.0816         -0.0578     0.4860    0.1364
# DUT_HOME         0.2152        0.1315          0.2150     1.7444    0.0909
#           eCDF Max Std. Pair Dist.
# LC_SOCIAL   0.3043          0.8003
# LC_SYSTEM   0.3043          0.4812
# LC_WORK     0.5652          0.9114
# UT_SOCIAL   0.1739          0.4056
# UT_SYSTEM   0.2609          0.4300
# DUT_HOME    0.1304          0.3041
#
# Sample Sizes:
#           Control Treated
# All           367      23
# Matched        23      23
# Unmatched     344       0
# Discarded       0       0
#
#
# $m.max_smd
# [1] 0.9113725
#
# $m.treated
# [1] 23
#
# $m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept) 0.564458   0.064787  8.7125 3.918e-11 ***
# treat       0.183060   0.081712  2.2403   0.03017 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
# $m.out
#            G0 G1
# All       367 23
# Matched     5  3
# Unmatched 362 20
#
#
# $m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_SOCIAL Contin.  0.8284   0.5530
# LC_SYSTEM Contin.  1.0311   0.1317
# LC_WORK   Contin.  1.1171   0.5347
# UT_SOCIAL Contin.  0.4653   0.0866
# UT_SYSTEM Contin.  0.4067   0.0571
# DUT_HOME  Contin. -0.1346   0.0000
#
# Sample sizes
#           Control Treated
# All           367      23
# Matched         2       2
# Unmatched     365      21
#
# $m.att
#
#            G0 G1
# All       367 23
# Matched     2  2
# Unmatched 365 21
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: -0.141310 (p.value=0.688192)
# 95% conf. interval: [-0.738082, 0.455462]
#
#
# $m.treated
# [1] 3
#
# $n_error
# [1] 0

# %%
individual = function(treatment, outcome, df, n_cutpoint_sampling){
    correlates = sigCorr(df, outcome)
    variables = append(outcome, correlates)
    idx = match(treatment, correlates)
    if(!is.na(idx))
        confoundings = correlates[-idx]
    else
        confoundings = correlates
    
    df$treat = ifelse(df[,treatment]>mean(df[,treatment]), 1, 0)

    formula =  paste("treat ~ ", paste(confoundings, collapse= " + "), sep = "")
    
    out = list()
    out$formula = formula    
    if(length(confoundings) > 0){
        out$ps.nearest = causal_inference(df,formula, outcome, distance = "PS",method = "nearest")
        out$ps.full = causal_inference(df,formula, outcome, distance = "PS",method = "full")
        out$mahalanobis = causal_inference(df,formula, outcome, distance = "Mahalanobis")
        out$cem = causal_inference(df, formula, outcome, distance = "CEM", n_cutpoint_sampling = n_cutpoint_sampling)
    }else{
        out$att = mean(df[which(df$treat ==  1),outcome]) - mean(df[which(df$treat == 0), outcome]) 
    }
    

    return(out)
}

datadir = 'Data/15Min'
result = list()
csv = "P3.csv"
df = read.csv(paste(datadir, csv, sep="/"))

out = list()
out$pid = strsplit(csv, split=".csv")[[1]]
prepared = prepareData(df,TRUE)
out$removed = prepared$removed
out$sig_corr = sigCorr(prepared$df, "DUT_SEDENTARY")

idx = match(out$removed, app_usage)
idx = idx[!is.na(idx)]
if(length(idx) > 0){
    left = app_usage[-idx]
}else{
    left = app_usage
}
for(elem in left){
    out[[paste("result",elem,sep=".")]] = individual(elem, "DUT_SEDENTARY", prepared$df, 10)
}
result[[out$pid]] = out
# Out:
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group

# %%
print(result)
# Out:
# $P3
# $P3$pid
# [1] "P3"
#
# $P3$removed
# [1] "LC_HEALTH" "UT_HEALTH"
#
# $P3$sig_corr
# [1] "LC_INFO"   "LC_SOCIAL" "LC_SYSTEM" "UT_INFO"   "UT_SOCIAL" "UT_SYSTEM"
# [7] "DUT_HOME"
#
# $P3$result.LC_ENTER
# $P3$result.LC_ENTER$formula
# [1] "treat ~ LC_INFO + LC_SOCIAL + LC_SYSTEM + UT_INFO + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.LC_ENTER$ps.nearest
# $P3$result.LC_ENTER$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 112 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_ENTER$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.2493        0.2398          0.0566     1.0186    0.0071
# LC_INFO          0.0556        0.0600         -0.0637     1.6702    0.0284
# LC_SOCIAL        0.0398        0.0425         -0.0306     1.2118    0.0198
# LC_SYSTEM        0.1574        0.1462          0.0539     0.8646    0.0429
# UT_INFO          0.0170        0.0212         -0.1443     1.0448    0.0547
# UT_SOCIAL        0.0794        0.0378          0.2153     5.8733    0.0427
# UT_SYSTEM        0.0882        0.0677          0.1358     1.4150    0.0675
# DUT_HOME         0.6104        0.6181         -0.0169     0.8924    0.0460
#           eCDF Max Std. Pair Dist.
# distance    0.0893          0.0871
# LC_INFO     0.1964          0.6442
# LC_SOCIAL   0.0714          0.8704
# LC_SYSTEM   0.1071          0.4526
# UT_INFO     0.1964          0.6346
# UT_SOCIAL   0.1071          0.5330
# UT_SYSTEM   0.1607          0.5271
# DUT_HOME    0.0893          0.5296
#
# Sample Sizes:
#           Control Treated
# All           401      56
# Matched        56      56
# Unmatched     345       0
# Discarded       0       0
#
#
# $P3$result.LC_ENTER$ps.nearest$m.max_smd
# [1] 0.215343
#
# $P3$result.LC_ENTER$ps.nearest$m.treated
# [1] 56
#
# $P3$result.LC_ENTER$ps.nearest$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.929100   0.030822 30.1442   <2e-16 ***
# treat       -0.036818   0.040023 -0.9199   0.3596
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_ENTER$ps.full
# $P3$result.LC_ENTER$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_ENTER$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.2493        0.2524         -0.0187     0.9300    0.0080
# LC_INFO          0.0556        0.0657         -0.1453     0.8181    0.0213
# LC_SOCIAL        0.0398        0.0597         -0.2261     1.0024    0.0548
# LC_SYSTEM        0.1574        0.2021         -0.2159     0.6820    0.0547
# UT_INFO          0.0170        0.0276         -0.3634     0.2642    0.0800
# UT_SOCIAL        0.0794        0.1119         -0.1684     0.9196    0.0954
# UT_SYSTEM        0.0882        0.0973         -0.0604     0.8542    0.0287
# DUT_HOME         0.6104        0.5851          0.0552     0.8684    0.0442
#           eCDF Max Std. Pair Dist.
# distance    0.0536          0.0222
# LC_INFO     0.1473          0.8396
# LC_SOCIAL   0.2042          0.7485
# LC_SYSTEM   0.1213          0.3774
# UT_INFO     0.2319          1.4119
# UT_SOCIAL   0.1972          0.7682
# UT_SYSTEM   0.0939          0.3890
# DUT_HOME    0.1160          0.2654
#
# Sample Sizes:
#               Control Treated
# All            401.        56
# Matched (ESS)   54.93      56
# Matched        401.        56
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.LC_ENTER$ps.full$m.max_smd
# [1] 0.3634034
#
# $P3$result.LC_ENTER$ps.full$m.treated
# [1] 56
#
# $P3$result.LC_ENTER$ps.full$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.928361   0.017789 52.1862   <2e-16 ***
# treat       -0.036079   0.031386 -1.1495   0.2509
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_ENTER$mahalanobis
# $P3$result.LC_ENTER$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 112 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_ENTER$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.0556        0.0575         -0.0283     1.4480    0.0211
# LC_SOCIAL        0.0398        0.0398          0.0000     1.2814    0.0139
# LC_SYSTEM        0.1574        0.1339          0.1132     1.2305    0.0250
# UT_INFO          0.0170        0.0191         -0.0720     1.4479    0.0529
# UT_SOCIAL        0.0794        0.0625          0.0877     1.5360    0.0176
# UT_SYSTEM        0.0882        0.0681          0.1334     1.1607    0.0686
# DUT_HOME         0.6104        0.5966          0.0300     0.8837    0.0412
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.1071          0.3539
# LC_SOCIAL   0.0714          0.0184
# LC_SYSTEM   0.0714          0.1886
# UT_INFO     0.1786          0.4946
# UT_SOCIAL   0.0536          0.1561
# UT_SYSTEM   0.1429          0.1954
# DUT_HOME    0.0893          0.1039
#
# Sample Sizes:
#           Control Treated
# All           401      56
# Matched        56      56
# Unmatched     345       0
# Discarded       0       0
#
#
# $P3$result.LC_ENTER$mahalanobis$m.max_smd
# [1] 0.1334295
#
# $P3$result.LC_ENTER$mahalanobis$m.treated
# [1] 56
#
# $P3$result.LC_ENTER$mahalanobis$m.att
#
# t test of coefficients:
#
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.8998244  0.0335425 26.8264   <2e-16 ***
# treat       -0.0075428  0.0485043 -0.1555   0.8767
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_ENTER$cem
# $P3$result.LC_ENTER$cem$m.out
#            G0 G1
# All       401 56
# Matched   280 45
# Unmatched 121 11
#
#
# $P3$result.LC_ENTER$cem$m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_INFO   Contin. -0.3618  -0.0674
# LC_SOCIAL Contin. -0.0455  -0.1435
# LC_SYSTEM Contin.  0.3587   0.0215
# UT_INFO   Contin. -1.3977  -0.0915
# UT_SOCIAL Contin. -0.1259  -0.0545
# UT_SYSTEM Contin.  0.2263  -0.0331
# DUT_HOME  Contin.  0.7339   0.9011
#
# Sample sizes
#                      Control Treated
# All                   401.        56
# Matched (ESS)         187.34      41
# Matched (Unweighted)  283.        41
# Unmatched             118.        15
#
# $P3$result.LC_ENTER$cem$m.att
#
#            G0 G1
# All       401 56
# Matched   283 41
# Unmatched 118 15
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: 0.039262 (p.value=0.265369)
# 95% conf. interval: [-0.029708, 0.108232]
#
#
# $P3$result.LC_ENTER$cem$m.treated
# [1] 45
#
# $P3$result.LC_ENTER$cem$n_error
# [1] 0
#
#
#
# $P3$result.LC_INFO
# $P3$result.LC_INFO$formula
# [1] "treat ~ LC_SOCIAL + LC_SYSTEM + UT_INFO + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.LC_INFO$ps.nearest
# $P3$result.LC_INFO$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 320 (matched)
#  - target estimand: ATT
#  - covariates: LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_INFO$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.7170        0.2280          1.6597     1.8471    0.4133
# LC_SOCIAL        0.0880        0.0329          0.5062     1.3403    0.1377
# LC_SYSTEM        0.1957        0.0672          0.6191     3.3281    0.1363
# UT_INFO          0.1309        0.0194          0.6690    13.4719    0.4578
# UT_SOCIAL        0.1334        0.0825          0.2680     0.8334    0.1618
# UT_SYSTEM        0.1109        0.0541          0.3260     1.5618    0.1861
# DUT_HOME         0.1864        0.1812          0.0136     1.0342    0.0060
#           eCDF Max Std. Pair Dist.
# distance    0.6688          1.6597
# LC_SOCIAL   0.3375          0.8088
# LC_SYSTEM   0.3500          0.8110
# UT_INFO     0.6938          0.6717
# UT_SOCIAL   0.3438          0.8456
# UT_SYSTEM   0.3562          0.6983
# DUT_HOME    0.0125          0.8261
#
# Sample Sizes:
#           Control Treated
# All           297     160
# Matched       160     160
# Unmatched     137       0
# Discarded       0       0
#
#
# $P3$result.LC_INFO$ps.nearest$m.max_smd
# [1] 0.6690131
#
# $P3$result.LC_INFO$ps.nearest$m.treated
# [1] 160
#
# $P3$result.LC_INFO$ps.nearest$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.87824    0.02034 43.1777 < 2.2e-16 ***
# treat       -0.11188    0.03266 -3.4256  0.000694 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_INFO$ps.full
# $P3$result.LC_INFO$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_INFO$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.7170        0.7165          0.0016     0.9211    0.0166
# LC_SOCIAL        0.0880        0.1269         -0.3575     0.1425    0.0560
# LC_SYSTEM        0.1957        0.1406          0.2656     1.0531    0.0655
# UT_INFO          0.1309        0.1410         -0.0606     0.9839    0.1321
# UT_SOCIAL        0.1334        0.1916         -0.3064     0.3636    0.0706
# UT_SYSTEM        0.1109        0.0930          0.1024     0.6880    0.0795
# DUT_HOME         0.1864        0.3637         -0.4663     0.5897    0.1716
#           eCDF Max Std. Pair Dist.
# distance    0.1563          0.0763
# LC_SOCIAL   0.1581          0.6558
# LC_SYSTEM   0.2006          0.4705
# UT_INFO     0.3000          0.2428
# UT_SOCIAL   0.1422          0.7167
# UT_SYSTEM   0.2006          0.4503
# DUT_HOME    0.1889          1.3493
#
# Sample Sizes:
#               Control Treated
# All            297.       160
# Matched (ESS)   11.87     160
# Matched        297.       160
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.LC_INFO$ps.full$m.max_smd
# [1] 0.4663255
#
# $P3$result.LC_INFO$ps.full$m.treated
# [1] 160
#
# $P3$result.LC_INFO$ps.full$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.914177   0.035822 25.5203 < 2.2e-16 ***
# treat       -0.147812   0.052935 -2.7923  0.005454 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_INFO$mahalanobis
# $P3$result.LC_INFO$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 320 (matched)
#  - target estimand: ATT
#  - covariates: LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_INFO$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_SOCIAL        0.0880        0.0282          0.5488     4.0469    0.1394
# LC_SYSTEM        0.1957        0.0672          0.6191     3.3281    0.1363
# UT_INFO          0.1309        0.0187          0.6732    13.8779    0.4613
# UT_SOCIAL        0.1334        0.0987          0.1825     0.7446    0.1322
# UT_SYSTEM        0.1109        0.0549          0.3215     1.5511    0.1847
# DUT_HOME         0.1864        0.2958         -0.2878     0.7442    0.1050
#           eCDF Max Std. Pair Dist.
# LC_SOCIAL   0.3250          0.6114
# LC_SYSTEM   0.3500          0.6793
# UT_INFO     0.7000          0.6799
# UT_SOCIAL   0.3000          0.4596
# UT_SYSTEM   0.3562          0.4306
# DUT_HOME    0.1375          0.3267
#
# Sample Sizes:
#           Control Treated
# All           297     160
# Matched       160     160
# Unmatched     137       0
# Discarded       0       0
#
#
# $P3$result.LC_INFO$mahalanobis$m.max_smd
# [1] 0.6731886
#
# $P3$result.LC_INFO$mahalanobis$m.treated
# [1] 160
#
# $P3$result.LC_INFO$mahalanobis$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.888692   0.019889 44.6821  < 2e-16 ***
# treat       -0.122328   0.031878 -3.8374  0.00015 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_INFO$cem
# $P3$result.LC_INFO$cem$m.out
#            G0  G1
# All       297 160
# Matched   270  83
# Unmatched  27  77
#
#
# $P3$result.LC_INFO$cem$m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_SOCIAL Contin.  0.6313   0.2101
# LC_SYSTEM Contin.  0.7673   0.3753
# UT_INFO   Contin.  0.7226   0.3299
# UT_SOCIAL Contin.  0.2647   0.0660
# UT_SYSTEM Contin.  0.4655   0.0798
# DUT_HOME  Contin. -0.5215   0.0052
#
# Sample sizes
#                      Control Treated
# All                   297.       160
# Matched (ESS)         128.57     103
# Matched (Unweighted)  271.       103
# Unmatched              26.        57
#
# $P3$result.LC_INFO$cem$m.att
#
#            G0  G1
# All       297 160
# Matched   271 103
# Unmatched  26  57
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: -0.059455 (p.value=0.063011)
# 95% conf. interval: [-0.121947, 0.003038]
#
#
# $P3$result.LC_INFO$cem$m.treated
# [1] 83
#
# $P3$result.LC_INFO$cem$n_error
# [1] 0
#
#
#
# $P3$result.LC_SOCIAL
# $P3$result.LC_SOCIAL$formula
# [1] "treat ~ LC_INFO + LC_SYSTEM + UT_INFO + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.LC_SOCIAL$ps.nearest
# $P3$result.LC_SOCIAL$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 252 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_SOCIAL$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.5672        0.3215          0.8338     1.5614    0.2084
# LC_INFO          0.1592        0.1067          0.3546     1.9962    0.0804
# LC_SYSTEM        0.2034        0.1166          0.4344     1.4063    0.0947
# UT_INFO          0.0982        0.0718          0.1795     1.2426    0.1067
# UT_SOCIAL        0.2536        0.1106          0.5525     0.9716    0.3447
# UT_SYSTEM        0.0968        0.0715          0.1512     1.4424    0.1021
# DUT_HOME         0.1866        0.2392         -0.1363     0.8866    0.0504
#           eCDF Max Std. Pair Dist.
# distance    0.3968          0.8340
# LC_INFO     0.1905          0.7092
# LC_SYSTEM   0.2381          0.8514
# UT_INFO     0.1746          0.6882
# UT_SOCIAL   0.7381          0.9357
# UT_SYSTEM   0.2460          0.6872
# DUT_HOME    0.0873          0.8496
#
# Sample Sizes:
#           Control Treated
# All           331     126
# Matched       126     126
# Unmatched     205       0
# Discarded       0       0
#
#
# $P3$result.LC_SOCIAL$ps.nearest$m.max_smd
# [1] 0.5525256
#
# $P3$result.LC_SOCIAL$ps.nearest$m.treated
# [1] 126
#
# $P3$result.LC_SOCIAL$ps.nearest$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.847824   0.024978 33.9427  < 2e-16 ***
# treat       -0.072294   0.035589 -2.0314  0.04328 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_SOCIAL$ps.full
# $P3$result.LC_SOCIAL$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_SOCIAL$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.5672        0.5641          0.0106     0.9956    0.0096
# LC_INFO          0.1592        0.1947         -0.2402     0.5385    0.0631
# LC_SYSTEM        0.2034        0.2032          0.0010     0.4960    0.0536
# UT_INFO          0.0982        0.1672         -0.4697     0.3624    0.0745
# UT_SOCIAL        0.2536        0.1835          0.2709     0.5536    0.2737
# UT_SYSTEM        0.0968        0.1195         -0.1357     0.6518    0.0504
# DUT_HOME         0.1866        0.1151          0.1856     1.5356    0.0689
#           eCDF Max Std. Pair Dist.
# distance    0.0952          0.0367
# LC_INFO     0.1190          0.5153
# LC_SYSTEM   0.1513          0.3941
# UT_INFO     0.1497          0.5664
# UT_SOCIAL   0.6221          0.4558
# UT_SYSTEM   0.1527          0.3956
# DUT_HOME    0.0843          1.0934
#
# Sample Sizes:
#               Control Treated
# All            331.       126
# Matched (ESS)   28.45     126
# Matched        331.       126
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.LC_SOCIAL$ps.full$m.max_smd
# [1] 0.4697114
#
# $P3$result.LC_SOCIAL$ps.full$m.treated
# [1] 126
#
# $P3$result.LC_SOCIAL$ps.full$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.849075   0.036856  23.038  < 2e-16 ***
# treat       -0.073545   0.030428  -2.417  0.01604 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_SOCIAL$mahalanobis
# $P3$result.LC_SOCIAL$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 252 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_SOCIAL$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.1592        0.1007          0.3948     2.3845    0.0895
# LC_SYSTEM        0.2034        0.1071          0.4816     1.4493    0.1048
# UT_INFO          0.0982        0.0655          0.2228     1.5215    0.1271
# UT_SOCIAL        0.2536        0.1092          0.5579     0.9768    0.3450
# UT_SYSTEM        0.0968        0.0637          0.1979     1.4626    0.1304
# DUT_HOME         0.1866        0.3028         -0.3014     0.7538    0.1117
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.2063          0.5110
# LC_SYSTEM   0.2857          0.5461
# UT_INFO     0.2143          0.3467
# UT_SOCIAL   0.7302          0.6490
# UT_SYSTEM   0.2937          0.3000
# DUT_HOME    0.1508          0.3318
#
# Sample Sizes:
#           Control Treated
# All           331     126
# Matched       126     126
# Unmatched     205       0
# Discarded       0       0
#
#
# $P3$result.LC_SOCIAL$mahalanobis$m.max_smd
# [1] 0.5579078
#
# $P3$result.LC_SOCIAL$mahalanobis$m.treated
# [1] 126
#
# $P3$result.LC_SOCIAL$mahalanobis$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.851161   0.025880 32.8883  < 2e-16 ***
# treat       -0.075631   0.035052 -2.1577  0.03191 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_SOCIAL$cem
# $P3$result.LC_SOCIAL$cem$m.out
#            G0  G1
# All       331 126
# Matched   283  62
# Unmatched  48  64
#
#
# $P3$result.LC_SOCIAL$cem$m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_INFO   Contin.  0.7592   0.2145
# LC_SYSTEM Contin.  0.7683   0.0665
# UT_INFO   Contin.  0.4281   0.0896
# UT_SOCIAL Contin.  0.8155   0.3484
# UT_SYSTEM Contin.  0.3187  -0.0070
# DUT_HOME  Contin. -0.4607   0.0046
#
# Sample sizes
#                      Control Treated
# All                   331.       126
# Matched (ESS)          79.02      71
# Matched (Unweighted)  277.        71
# Unmatched              54.        55
#
# $P3$result.LC_SOCIAL$cem$m.att
#
#            G0  G1
# All       331 126
# Matched   277  71
# Unmatched  54  55
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: 0.003928 (p.value=0.922985)
# 95% conf. interval: [-0.075656, 0.083512]
#
#
# $P3$result.LC_SOCIAL$cem$m.treated
# [1] 62
#
# $P3$result.LC_SOCIAL$cem$n_error
# [1] 0
#
#
#
# $P3$result.LC_SYSTEM
# $P3$result.LC_SYSTEM$formula
# [1] "treat ~ LC_INFO + LC_SOCIAL + UT_INFO + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.LC_SYSTEM$ps.nearest
# $P3$result.LC_SYSTEM$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 280 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_SYSTEM$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.6734        0.2507          1.3340     2.0352    0.3409
# LC_INFO          0.1583        0.0931          0.4330     3.1785    0.0994
# LC_SOCIAL        0.0919        0.0492          0.3866     1.1178    0.1087
# UT_INFO          0.1017        0.0615          0.2466     2.5332    0.0852
# UT_SOCIAL        0.1696        0.1589          0.0462     0.6312    0.0812
# UT_SYSTEM        0.1704        0.0196          0.7408    11.4171    0.4637
# DUT_HOME         0.2132        0.2963         -0.2101     0.7727    0.0805
#           eCDF Max Std. Pair Dist.
# distance    0.5857          1.3340
# LC_INFO     0.2357          0.7858
# LC_SOCIAL   0.2429          0.8752
# UT_INFO     0.1500          0.6782
# UT_SOCIAL   0.1286          1.0218
# UT_SYSTEM   0.7643          0.7408
# DUT_HOME    0.1071          0.9700
#
# Sample Sizes:
#           Control Treated
# All           317     140
# Matched       140     140
# Unmatched     177       0
# Discarded       0       0
#
#
# $P3$result.LC_SYSTEM$ps.nearest$m.max_smd
# [1] 0.740793
#
# $P3$result.LC_SYSTEM$ps.nearest$m.treated
# [1] 140
#
# $P3$result.LC_SYSTEM$ps.nearest$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.869881   0.021451 40.5518 < 2.2e-16 ***
# treat       -0.106779   0.034928 -3.0572  0.002452 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_SYSTEM$ps.full
# $P3$result.LC_SYSTEM$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_SYSTEM$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.6734        0.6713          0.0069     0.9325    0.0189
# LC_INFO          0.1583        0.1286          0.1973     1.1526    0.0535
# LC_SOCIAL        0.0919        0.1100         -0.1646     0.2409    0.0663
# UT_INFO          0.1017        0.1322         -0.1874     0.9144    0.0900
# UT_SOCIAL        0.1696        0.1965         -0.1168     0.4434    0.0820
# UT_SYSTEM        0.1704        0.1341          0.1781     1.7475    0.1478
# DUT_HOME         0.2132        0.1918          0.0541     0.9778    0.0205
#           eCDF Max Std. Pair Dist.
# distance    0.2143          0.0667
# LC_INFO     0.2013          0.7228
# LC_SOCIAL   0.2083          0.8462
# UT_INFO     0.2332          1.9830
# UT_SOCIAL   0.1630          0.5444
# UT_SYSTEM   0.2894          0.2280
# DUT_HOME    0.0449          0.9817
#
# Sample Sizes:
#               Control Treated
# All            317.       140
# Matched (ESS)   13.88     140
# Matched        317.       140
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.LC_SYSTEM$ps.full$m.max_smd
# [1] 0.1973199
#
# $P3$result.LC_SYSTEM$ps.full$m.treated
# [1] 140
#
# $P3$result.LC_SYSTEM$ps.full$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.893184   0.034598 25.8164  < 2e-16 ***
# treat       -0.130083   0.065537 -1.9849  0.04776 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_SYSTEM$mahalanobis
# $P3$result.LC_SYSTEM$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 280 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_SYSTEM$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.1583        0.0923          0.4383     3.0951    0.1006
# LC_SOCIAL        0.0919        0.0417          0.4553     2.7774    0.1161
# UT_INFO          0.1017        0.0676          0.2094     2.1109    0.0839
# UT_SOCIAL        0.1696        0.1169          0.2285     0.9898    0.1103
# UT_SYSTEM        0.1704        0.0191          0.7435    11.4856    0.4676
# DUT_HOME         0.2132        0.2993         -0.2178     0.7841    0.0835
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.2357          0.5068
# LC_SOCIAL   0.2500          0.5043
# UT_INFO     0.1357          0.3809
# UT_SOCIAL   0.1714          0.3820
# UT_SYSTEM   0.7714          0.7445
# DUT_HOME    0.1000          0.2439
#
# Sample Sizes:
#           Control Treated
# All           317     140
# Matched       140     140
# Unmatched     177       0
# Discarded       0       0
#
#
# $P3$result.LC_SYSTEM$mahalanobis$m.max_smd
# [1] 0.7435125
#
# $P3$result.LC_SYSTEM$mahalanobis$m.treated
# [1] 140
#
# $P3$result.LC_SYSTEM$mahalanobis$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.865041   0.021894 39.5107 < 2.2e-16 ***
# treat       -0.101939   0.028165 -3.6193 0.0003508 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_SYSTEM$cem
# $P3$result.LC_SYSTEM$cem$m.out
#            G0  G1
# All       317 140
# Matched   273  67
# Unmatched  44  73
#
#
# $P3$result.LC_SYSTEM$cem$m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_INFO   Contin.  0.7702   0.7001
# LC_SOCIAL Contin.  0.6350   0.5671
# UT_INFO   Contin.  0.4339   0.3204
# UT_SOCIAL Contin.  0.4307   0.0845
# UT_SYSTEM Contin.  0.7946   0.4158
# DUT_HOME  Contin. -0.3720  -0.0046
#
# Sample sizes
#                      Control Treated
# All                   317.       140
# Matched (ESS)          81.31     124
# Matched (Unweighted)  303.       124
# Unmatched              14.        16
#
# $P3$result.LC_SYSTEM$cem$m.att
#
#            G0  G1
# All       317 140
# Matched   303 124
# Unmatched  14  16
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: -0.098564 (p.value=0.000427)
# 95% conf. interval: [-0.152970, -0.044158]
#
#
# $P3$result.LC_SYSTEM$cem$m.treated
# [1] 67
#
# $P3$result.LC_SYSTEM$cem$n_error
# [1] 0
#
#
#
# $P3$result.LC_WORK
# $P3$result.LC_WORK$formula
# [1] "treat ~ LC_INFO + LC_SOCIAL + LC_SYSTEM + UT_INFO + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.LC_WORK$ps.nearest
# $P3$result.LC_WORK$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 34 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_WORK$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.1211        0.1138          0.0554     1.2485    0.0047
# LC_INFO          0.1160        0.1797         -0.6547     0.3252    0.0963
# LC_SOCIAL        0.0704        0.0856         -0.1394     1.0457    0.0632
# LC_SYSTEM        0.3015        0.2831          0.0625     1.0297    0.0196
# UT_INFO          0.0522        0.0860         -0.5495     0.4656    0.1209
# UT_SOCIAL        0.1242        0.1212          0.0151     1.0772    0.0574
# UT_SYSTEM        0.1909        0.2839         -0.3970     0.5345    0.0696
# DUT_HOME         0.2276        0.1562          0.1688     1.5120    0.0588
#           eCDF Max Std. Pair Dist.
# distance    0.1765          0.0644
# LC_INFO     0.1765          1.3261
# LC_SOCIAL   0.1765          1.1230
# LC_SYSTEM   0.0588          0.0875
# UT_INFO     0.3529          0.7975
# UT_SOCIAL   0.1765          0.9787
# UT_SYSTEM   0.2353          0.9465
# DUT_HOME    0.1176          0.6287
#
# Sample Sizes:
#           Control Treated
# All           440      17
# Matched        17      17
# Unmatched     423       0
# Discarded       0       0
#
#
# $P3$result.LC_WORK$ps.nearest$m.max_smd
# [1] 0.6546767
#
# $P3$result.LC_WORK$ps.nearest$m.treated
# [1] 17
#
# $P3$result.LC_WORK$ps.nearest$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept) 0.698597   0.092013  7.5924 1.194e-08 ***
# treat       0.177137   0.100857  1.7563    0.0886 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_WORK$ps.full
# $P3$result.LC_WORK$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_WORK$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.1211        0.1350         -0.1053     0.5980    0.0230
# LC_INFO          0.1160        0.1477         -0.3255     0.4411    0.0557
# LC_SOCIAL        0.0704        0.0889         -0.1705     0.7981    0.0563
# LC_SYSTEM        0.3015        0.3272         -0.0873     0.8798    0.0332
# UT_INFO          0.0522        0.0769         -0.4011     0.2399    0.0754
# UT_SOCIAL        0.1242        0.1647         -0.2029     0.6036    0.0524
# UT_SYSTEM        0.1909        0.2097         -0.0804     0.8854    0.0450
# DUT_HOME         0.2276        0.2211          0.0155     1.0968    0.0229
#           eCDF Max Std. Pair Dist.
# distance    0.1176          0.0251
# LC_INFO     0.1597          1.0572
# LC_SOCIAL   0.1788          0.8064
# LC_SYSTEM   0.0753          0.1024
# UT_INFO     0.2142          1.0875
# UT_SOCIAL   0.1410          0.6697
# UT_SYSTEM   0.1248          0.1657
# DUT_HOME    0.0793          0.4508
#
# Sample Sizes:
#               Control Treated
# All            440.        17
# Matched (ESS)   57.38      17
# Matched        440.        17
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.LC_WORK$ps.full$m.max_smd
# [1] 0.4010688
#
# $P3$result.LC_WORK$ps.full$m.treated
# [1] 17
#
# $P3$result.LC_WORK$ps.full$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.756618   0.061552  12.292  < 2e-16 ***
# treat       0.119116   0.070316   1.694  0.09095 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_WORK$mahalanobis
# $P3$result.LC_WORK$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 34 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.LC_WORK$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.1160        0.1225         -0.0671     1.1686    0.0267
# LC_SOCIAL        0.0704        0.0784         -0.0738     0.7934    0.0479
# LC_SYSTEM        0.3015        0.2574          0.1500     1.5428    0.0706
# UT_INFO          0.0522        0.0496          0.0416     1.7571    0.0517
# UT_SOCIAL        0.1242        0.1038          0.1023     1.2553    0.0613
# UT_SYSTEM        0.1909        0.1659          0.1067     1.2611    0.0378
# DUT_HOME         0.2276        0.2690         -0.0977     0.9460    0.0475
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.1765          0.4029
# LC_SOCIAL   0.1176          0.3689
# LC_SYSTEM   0.1765          0.2749
# UT_INFO     0.2353          0.6056
# UT_SOCIAL   0.1176          0.4666
# UT_SYSTEM   0.1176          0.2284
# DUT_HOME    0.1176          0.0977
#
# Sample Sizes:
#           Control Treated
# All           440      17
# Matched        17      17
# Unmatched     423       0
# Discarded       0       0
#
#
# $P3$result.LC_WORK$mahalanobis$m.max_smd
# [1] 0.1499692
#
# $P3$result.LC_WORK$mahalanobis$m.treated
# [1] 17
#
# $P3$result.LC_WORK$mahalanobis$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept) 0.733967   0.088972  8.2494 2.007e-09 ***
# treat       0.141768   0.103928  1.3641    0.1821
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.LC_WORK$cem
# $P3$result.LC_WORK$cem$m.out
#            G0 G1
# All       440 17
# Matched   244  8
# Unmatched 196  9
#
#
# $P3$result.LC_WORK$cem$m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_INFO   Contin.  0.4077   0.1124
# LC_SOCIAL Contin.  0.2590   0.1103
# LC_SYSTEM Contin.  0.7389  -0.0159
# UT_INFO   Contin. -0.0080   0.1114
# UT_SOCIAL Contin.  0.1220   0.0165
# UT_SYSTEM Contin.  0.5884  -0.0785
# DUT_HOME  Contin. -0.2150  -0.0387
#
# Sample sizes
#                      Control Treated
# All                   440.        17
# Matched (ESS)          52.94       8
# Matched (Unweighted)  244.         8
# Unmatched             196.         9
#
# $P3$result.LC_WORK$cem$m.att
#
#            G0 G1
# All       440 17
# Matched   244  8
# Unmatched 196  9
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: 0.053864 (p.value=0.618211)
# 95% conf. interval: [-0.157698, 0.265427]
#
#
# $P3$result.LC_WORK$cem$m.treated
# [1] 8
#
# $P3$result.LC_WORK$cem$n_error
# [1] 0
#
#
#
# $P3$result.UT_ENTER
# $P3$result.UT_ENTER$formula
# [1] "treat ~ LC_INFO + LC_SOCIAL + LC_SYSTEM + UT_INFO + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.UT_ENTER$ps.nearest
# $P3$result.UT_ENTER$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 88 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_ENTER$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.2973        0.2720          0.1382     1.1764    0.0083
# LC_INFO          0.0429        0.0410          0.0283     1.6487    0.0176
# LC_SOCIAL        0.0265        0.0427         -0.2883     0.4185    0.0379
# LC_SYSTEM        0.1420        0.1392          0.0132     0.7823    0.0515
# UT_INFO          0.0106        0.0122         -0.0799     1.0587    0.0310
# UT_SOCIAL        0.0222        0.0376         -0.2425     0.3230    0.0269
# UT_SYSTEM        0.0801        0.0755          0.0318     0.7164    0.0795
# DUT_HOME         0.7618        0.7925         -0.0778     0.9375    0.0463
#           eCDF Max Std. Pair Dist.
# distance    0.1364          0.2029
# LC_INFO     0.0909          0.5384
# LC_SOCIAL   0.0909          0.7913
# LC_SYSTEM   0.1136          0.6223
# UT_INFO     0.1364          0.6139
# UT_SOCIAL   0.0909          0.7295
# UT_SYSTEM   0.1591          0.7248
# DUT_HOME    0.0909          0.5726
#
# Sample Sizes:
#           Control Treated
# All           413      44
# Matched        44      44
# Unmatched     369       0
# Discarded       0       0
#
#
# $P3$result.UT_ENTER$ps.nearest$m.max_smd
# [1] 0.2883111
#
# $P3$result.UT_ENTER$ps.nearest$m.treated
# [1] 44
#
# $P3$result.UT_ENTER$ps.nearest$m.att
#
# t test of coefficients:
#
#                Estimate  Std. Error t value Pr(>|t|)
# (Intercept)  0.96114821  0.02346369 40.9632   <2e-16 ***
# treat       -0.00093604  0.03040872 -0.0308   0.9755
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_ENTER$ps.full
# $P3$result.UT_ENTER$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_ENTER$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.2973        0.3057         -0.0457     0.8142    0.0097
# LC_INFO          0.0429        0.0563         -0.2002     0.9560    0.0305
# LC_SOCIAL        0.0265        0.0487         -0.3949     0.3348    0.0504
# LC_SYSTEM        0.1420        0.1668         -0.1154     0.6461    0.0604
# UT_INFO          0.0106        0.0177         -0.3643     0.2499    0.0593
# UT_SOCIAL        0.0222        0.0342         -0.1894     0.5586    0.0381
# UT_SYSTEM        0.0801        0.0786          0.0105     0.9483    0.0634
# DUT_HOME         0.7618        0.7824         -0.0522     0.9086    0.0445
#           eCDF Max Std. Pair Dist.
# distance    0.0682          0.0301
# LC_INFO     0.1424          0.9176
# LC_SOCIAL   0.1005          0.9244
# LC_SYSTEM   0.1240          0.4373
# UT_INFO     0.1557          2.5857
# UT_SOCIAL   0.1200          1.6990
# UT_SYSTEM   0.1331          0.4614
# DUT_HOME    0.0901          0.4430
#
# Sample Sizes:
#               Control Treated
# All             413.       44
# Matched (ESS)    39.9      44
# Matched         413.       44
# Unmatched         0.        0
# Discarded         0.        0
#
#
# $P3$result.UT_ENTER$ps.full$m.max_smd
# [1] 0.394913
#
# $P3$result.UT_ENTER$ps.full$m.treated
# [1] 44
#
# $P3$result.UT_ENTER$ps.full$m.att
#
# t test of coefficients:
#
#                Estimate  Std. Error t value Pr(>|t|)
# (Intercept)  0.96120742  0.01197528 80.2660   <2e-16 ***
# treat       -0.00099525  0.02205397 -0.0451    0.964
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_ENTER$mahalanobis
# $P3$result.UT_ENTER$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 88 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_ENTER$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.0429        0.0467         -0.0567     1.7585    0.0289
# LC_SOCIAL        0.0265        0.0251          0.0245     1.2198    0.0118
# LC_SYSTEM        0.1420        0.1108          0.1457     1.4245    0.0303
# UT_INFO          0.0106        0.0165         -0.3049     0.8697    0.0737
# UT_SOCIAL        0.0222        0.0233         -0.0175     0.6699    0.0100
# UT_SYSTEM        0.0801        0.0560          0.1661     1.3533    0.0753
# DUT_HOME         0.7618        0.7551          0.0171     0.8456    0.0411
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.1818          0.3779
# LC_SOCIAL   0.0455          0.3190
# LC_SYSTEM   0.0909          0.1589
# UT_INFO     0.2273          0.6300
# UT_SOCIAL   0.0682          0.2236
# UT_SYSTEM   0.1364          0.1780
# DUT_HOME    0.0682          0.1265
#
# Sample Sizes:
#           Control Treated
# All           413      44
# Matched        44      44
# Unmatched     369       0
# Discarded       0       0
#
#
# $P3$result.UT_ENTER$mahalanobis$m.max_smd
# [1] 0.3049417
#
# $P3$result.UT_ENTER$mahalanobis$m.treated
# [1] 44
#
# $P3$result.UT_ENTER$mahalanobis$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.922116   0.033747 27.3243   <2e-16 ***
# treat       0.038096   0.040030  0.9517   0.3439
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_ENTER$cem
# $P3$result.UT_ENTER$cem$n_error
# [1] 0
#
#
#
# $P3$result.UT_INFO
# $P3$result.UT_INFO$formula
# [1] "treat ~ LC_INFO + LC_SOCIAL + LC_SYSTEM + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.UT_INFO$ps.nearest
# $P3$result.UT_INFO$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 218 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_INFO$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.6582        0.2751          1.2029     1.8803    0.2434
# LC_INFO          0.2143        0.0923          0.7864     9.9839    0.1885
# LC_SOCIAL        0.0976        0.0602          0.2590     2.9909    0.0714
# LC_SYSTEM        0.1732        0.1107          0.3335     1.4257    0.0667
# UT_SOCIAL        0.1293        0.1169          0.0644     0.8154    0.0574
# UT_SYSTEM        0.0999        0.0713          0.1771     1.3454    0.1055
# DUT_HOME         0.1518        0.2459         -0.2664     0.7129    0.0910
#           eCDF Max Std. Pair Dist.
# distance    0.5229          1.2029
# LC_INFO     0.4954          0.7864
# LC_SOCIAL   0.1284          0.7384
# LC_SYSTEM   0.1743          0.8719
# UT_SOCIAL   0.1284          0.9493
# UT_SYSTEM   0.2018          0.8299
# DUT_HOME    0.1284          0.8354
#
# Sample Sizes:
#           Control Treated
# All           348     109
# Matched       109     109
# Unmatched     239       0
# Discarded       0       0
#
#
# $P3$result.UT_INFO$ps.nearest$m.max_smd
# [1] 0.7864395
#
# $P3$result.UT_INFO$ps.nearest$m.treated
# [1] 109
#
# $P3$result.UT_INFO$ps.nearest$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.880612   0.023327 37.7509 < 2.2e-16 ***
# treat       -0.170054   0.038473 -4.4201 1.562e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_INFO$ps.full
# $P3$result.UT_INFO$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_INFO$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.6582        0.6536          0.0146     0.9441    0.0214
# LC_INFO          0.2143        0.1773          0.2383     3.4924    0.0568
# LC_SOCIAL        0.0976        0.0926          0.0344     3.6321    0.1140
# LC_SYSTEM        0.1732        0.2141         -0.2185     0.8063    0.0548
# UT_SOCIAL        0.1293        0.1034          0.1349     1.1418    0.1054
# UT_SYSTEM        0.0999        0.1009         -0.0058     1.1462    0.0589
# DUT_HOME         0.1518        0.1854         -0.0951     0.8229    0.0330
#           eCDF Max Std. Pair Dist.
# distance    0.2661          0.0196
# LC_INFO     0.2110          0.1790
# LC_SOCIAL   0.1820          0.5138
# LC_SYSTEM   0.1933          0.7418
# UT_SOCIAL   0.2478          2.3121
# UT_SYSTEM   0.1838          0.4105
# DUT_HOME    0.0581          1.3179
#
# Sample Sizes:
#               Control Treated
# All            348.       109
# Matched (ESS)   10.71     109
# Matched        348.       109
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.UT_INFO$ps.full$m.max_smd
# [1] 0.2382644
#
# $P3$result.UT_INFO$ps.full$m.treated
# [1] 109
#
# $P3$result.UT_INFO$ps.full$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.869244   0.064399 13.4977  < 2e-16 ***
# treat       -0.158686   0.065946 -2.4063  0.01651 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_INFO$mahalanobis
# $P3$result.UT_INFO$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 218 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_INFO$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.2143        0.0884          0.8111    10.3974    0.1947
# LC_SOCIAL        0.0976        0.0553          0.2927     3.6178    0.0826
# LC_SYSTEM        0.1732        0.1261          0.2509     1.4118    0.0502
# UT_SOCIAL        0.1293        0.1108          0.0962     1.0185    0.0458
# ...
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.1406        0.1040          0.2319     2.4993    0.0584
# LC_SOCIAL        0.1350        0.0594          0.5169     4.5755    0.1602
# LC_SYSTEM        0.1945        0.1390          0.2649     1.1909    0.0619
# UT_INFO          0.0903        0.0611          0.1844     2.4429    0.0633
# UT_SYSTEM        0.1004        0.0778          0.1251     1.4115    0.0700
# DUT_HOME         0.2564        0.2645         -0.0190     0.9513    0.0102
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.1122          0.3901
# LC_SOCIAL   0.4082          0.5550
# LC_SYSTEM   0.1429          0.3562
# UT_INFO     0.1429          0.2972
# UT_SYSTEM   0.1429          0.2441
# DUT_HOME    0.0306          0.1008
#
# Sample Sizes:
#           Control Treated
# All           359      98
# Matched        98      98
# Unmatched     261       0
# Discarded       0       0
#
#
# $P3$result.UT_SOCIAL$mahalanobis$m.max_smd
# [1] 0.5169259
#
# $P3$result.UT_SOCIAL$mahalanobis$m.treated
# [1] 98
#
# $P3$result.UT_SOCIAL$mahalanobis$m.att
#
# t test of coefficients:
#
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.8136286  0.0315972 25.7500   <2e-16 ***
# treat       -0.0044595  0.0407779 -0.1094    0.913
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_SOCIAL$cem
# $P3$result.UT_SOCIAL$cem$m.out
#            G0 G1
# All       359 98
# Matched   311 62
# Unmatched  48 36
#
#
# $P3$result.UT_SOCIAL$cem$m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_INFO   Contin.  0.5069   0.0277
# LC_SOCIAL Contin.  0.7979   0.2613
# LC_SYSTEM Contin.  0.6219   0.1446
# UT_INFO   Contin.  0.3027  -0.0123
# UT_SYSTEM Contin.  0.2966   0.0412
# DUT_HOME  Contin. -0.1759   0.0029
#
# Sample sizes
#                      Control Treated
# All                   359.        98
# Matched (ESS)         154.35      53
# Matched (Unweighted)  281.        53
# Unmatched              78.        45
#
# $P3$result.UT_SOCIAL$cem$m.att
#
#            G0 G1
# All       359 98
# Matched   281 53
# Unmatched  78 45
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: -0.029481 (p.value=0.411989)
# 95% conf. interval: [-0.099823, 0.040861]
#
#
# $P3$result.UT_SOCIAL$cem$m.treated
# [1] 62
#
# $P3$result.UT_SOCIAL$cem$n_error
# [1] 0
#
#
#
# $P3$result.UT_SYSTEM
# $P3$result.UT_SYSTEM$formula
# [1] "treat ~ LC_INFO + LC_SOCIAL + LC_SYSTEM + UT_INFO + UT_SOCIAL + DUT_HOME"
#
# $P3$result.UT_SYSTEM$ps.nearest
# $P3$result.UT_SYSTEM$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 196 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, DUT_HOME
#
# $P3$result.UT_SYSTEM$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.6842        0.2453          1.2950     2.0932    0.2297
# LC_INFO          0.1621        0.1145          0.2966     2.0905    0.0691
# LC_SOCIAL        0.0991        0.0733          0.1726     2.9428    0.0506
# LC_SYSTEM        0.3163        0.1116          0.9929     6.8326    0.2170
# UT_INFO          0.1057        0.0726          0.1978     1.9583    0.0649
# UT_SOCIAL        0.1570        0.1349          0.0983     1.1530    0.0339
# DUT_HOME         0.2005        0.2004          0.0002     0.9158    0.0216
#           eCDF Max Std. Pair Dist.
# distance    0.5714          1.2950
# LC_INFO     0.1531          0.8120
# LC_SOCIAL   0.1327          0.7185
# LC_SYSTEM   0.5204          0.9929
# UT_INFO     0.1633          0.7372
# UT_SOCIAL   0.1224          0.9535
# DUT_HOME    0.0408          0.8253
#
# Sample Sizes:
#           Control Treated
# All           359      98
# Matched        98      98
# Unmatched     261       0
# Discarded       0       0
#
#
# $P3$result.UT_SYSTEM$ps.nearest$m.max_smd
# [1] 0.9929066
#
# $P3$result.UT_SYSTEM$ps.nearest$m.treated
# [1] 98
#
# $P3$result.UT_SYSTEM$ps.nearest$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.863949   0.025744 33.5592 < 2.2e-16 ***
# treat       -0.154906   0.047658 -3.2503  0.001359 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_SYSTEM$ps.full
# $P3$result.UT_SYSTEM$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, DUT_HOME
#
# $P3$result.UT_SYSTEM$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.6842        0.6735          0.0314     0.8881    0.0356
# LC_INFO          0.1621        0.1182          0.2737     3.4414    0.0943
# LC_SOCIAL        0.0991        0.1697         -0.4723     1.0221    0.1983
# LC_SYSTEM        0.3163        0.2368          0.3859     3.4557    0.0835
# UT_INFO          0.1057        0.0580          0.2850     1.8332    0.1558
# UT_SOCIAL        0.1570        0.1930         -0.1599     0.9864    0.1297
# DUT_HOME         0.2005        0.1044          0.2539     1.3343    0.0928
#           eCDF Max Std. Pair Dist.
# distance    0.3469          0.1221
# LC_INFO     0.2026          0.6073
# LC_SOCIAL   0.2944          0.2996
# LC_SYSTEM   0.2857          0.3089
# UT_INFO     0.2429          0.8388
# UT_SOCIAL   0.2419          0.4968
# DUT_HOME    0.1445          0.9032
#
# Sample Sizes:
#               Control Treated
# All            359.        98
# Matched (ESS)    6.98      98
# Matched        359.        98
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.UT_SYSTEM$ps.full$m.max_smd
# [1] 0.4723444
#
# $P3$result.UT_SYSTEM$ps.full$m.treated
# [1] 98
#
# $P3$result.UT_SYSTEM$ps.full$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.920699   0.033532 27.4570 < 2.2e-16 ***
# treat       -0.211656   0.047480 -4.4578 1.044e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_SYSTEM$mahalanobis
# $P3$result.UT_SYSTEM$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 196 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, DUT_HOME
#
# $P3$result.UT_SYSTEM$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.1621        0.1250          0.2312     1.8475    0.0529
# LC_SOCIAL        0.0991        0.0685          0.2047     2.8341    0.0525
# LC_SYSTEM        0.3163        0.1103          0.9991     6.6981    0.2184
# UT_INFO          0.1057        0.0904          0.0915     1.3267    0.0371
# UT_SOCIAL        0.1570        0.1429          0.0631     1.0252    0.0245
# DUT_HOME         0.2005        0.2146         -0.0374     0.8780    0.0200
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.1327          0.3583
# LC_SOCIAL   0.1327          0.3680
# LC_SYSTEM   0.5204          1.0177
# UT_INFO     0.1122          0.2792
# UT_SOCIAL   0.1020          0.3483
# DUT_HOME    0.0510          0.1279
#
# Sample Sizes:
#           Control Treated
# All           359      98
# Matched        98      98
# Unmatched     261       0
# Discarded       0       0
#
#
# $P3$result.UT_SYSTEM$mahalanobis$m.max_smd
# [1] 0.999093
#
# $P3$result.UT_SYSTEM$mahalanobis$m.treated
# [1] 98
#
# $P3$result.UT_SYSTEM$mahalanobis$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.861480   0.025431 33.8752 < 2.2e-16 ***
# treat       -0.152437   0.043099 -3.5369 0.0005065 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_SYSTEM$cem
# $P3$result.UT_SYSTEM$cem$m.out
#            G0 G1
# All       359 98
# Matched   281 36
# Unmatched  78 62
#
#
# $P3$result.UT_SYSTEM$cem$m.balance
# Balance Measures
#              Type Diff.Un Diff.Adj
# LC_INFO   Contin.  0.6685   0.0824
# LC_SOCIAL Contin.  0.4750   0.0076
# LC_SYSTEM Contin.  1.3839   1.1229
# UT_INFO   Contin.  0.4034   0.0014
# UT_SOCIAL Contin.  0.3185   0.0250
# DUT_HOME  Contin. -0.3862   0.0090
#
# Sample sizes
#                      Control Treated
# All                    359.       98
# Matched (ESS)          118.1      67
# Matched (Unweighted)   318.       67
# Unmatched               41.       31
#
# $P3$result.UT_SYSTEM$cem$m.att
#
#            G0 G1
# All       359 98
# Matched   318 67
# Unmatched  41 31
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: -0.117028 (p.value=0.001098)
# 95% conf. interval: [-0.186766, -0.047289]
#
#
# $P3$result.UT_SYSTEM$cem$m.treated
# [1] 36
#
# $P3$result.UT_SYSTEM$cem$n_error
# [1] 0
#
#
#
# $P3$result.UT_WORK
# $P3$result.UT_WORK$formula
# [1] "treat ~ LC_INFO + LC_SOCIAL + LC_SYSTEM + UT_INFO + UT_SOCIAL + UT_SYSTEM + DUT_HOME"
#
# $P3$result.UT_WORK$ps.nearest
# $P3$result.UT_WORK$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 22 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_WORK$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.1787        0.1776          0.0072     1.1169    0.0041
# LC_INFO          0.1540        0.2980         -1.4791     0.4035    0.2231
# LC_SOCIAL        0.1061        0.0937          0.1016     2.3173    0.0842
# LC_SYSTEM        0.4659        0.4261          0.1709     1.9365    0.0788
# UT_INFO          0.0558        0.1115         -1.0956     0.5479    0.2225
# UT_SOCIAL        0.1848        0.1905         -0.0252     0.9459    0.0630
# UT_SYSTEM        0.2950        0.2313          0.2740     2.2373    0.0531
# DUT_HOME         0.0862        0.0127          0.2570    75.1236    0.0699
#           eCDF Max Std. Pair Dist.
# distance    0.1818          0.0477
# LC_INFO     0.4545          1.9462
# LC_SOCIAL   0.1818          0.8696
# LC_SYSTEM   0.2727          0.4637
# UT_INFO     0.4545          1.5790
# UT_SOCIAL   0.1818          1.0697
# UT_SYSTEM   0.2727          0.6891
# DUT_HOME    0.0909          0.3460
#
# Sample Sizes:
#           Control Treated
# All           446      11
# Matched        11      11
# Unmatched     435       0
# Discarded       0       0
#
#
# $P3$result.UT_WORK$ps.nearest$m.max_smd
# [1] 1.479148
#
# $P3$result.UT_WORK$ps.nearest$m.treated
# [1] 11
#
# $P3$result.UT_WORK$ps.nearest$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.58942    0.10543  5.5904 1.797e-05 ***
# treat        0.23955    0.09568  2.5037   0.02107 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_WORK$ps.full
# $P3$result.UT_WORK$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_WORK$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance         0.1787        0.1837         -0.0318     0.7963    0.0376
# LC_INFO          0.1540        0.2206         -0.6839     0.2703    0.0992
# LC_SOCIAL        0.1061        0.1460         -0.3276     0.9875    0.1157
# LC_SYSTEM        0.4659        0.4292          0.1578     1.0348    0.0663
# UT_INFO          0.0558        0.0775         -0.4277     0.3627    0.0614
# UT_SOCIAL        0.1848        0.2048         -0.0880     0.8991    0.0666
# UT_SYSTEM        0.2950        0.2637          0.1348     0.8955    0.0649
# DUT_HOME         0.0862        0.0896         -0.0121     1.0366    0.0163
#           eCDF Max Std. Pair Dist.
# distance    0.0909          0.0697
# LC_INFO     0.2263          1.4234
# LC_SOCIAL   0.3600          2.4132
# LC_SYSTEM   0.1675          0.3028
# UT_INFO     0.1916          1.4120
# UT_SOCIAL   0.2119          0.6603
# UT_SYSTEM   0.2919          0.2240
# DUT_HOME    0.0798          1.1303
#
# Sample Sizes:
#               Control Treated
# All            446.        11
# Matched (ESS)   26.48      11
# Matched        446.        11
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $P3$result.UT_WORK$ps.full$m.max_smd
# [1] 0.6838866
#
# $P3$result.UT_WORK$ps.full$m.treated
# [1] 11
#
# $P3$result.UT_WORK$ps.full$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept) 0.666746   0.075232  8.8626 < 2.2e-16 ***
# treat       0.162231   0.052148  3.1110  0.001982 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_WORK$mahalanobis
# $P3$result.UT_WORK$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 22 (matched)
#  - target estimand: ATT
#  - covariates: LC_INFO, LC_SOCIAL, LC_SYSTEM, UT_INFO, UT_SOCIAL, UT_SYSTEM, DUT_HOME
#
# $P3$result.UT_WORK$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#           Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_INFO          0.1540        0.1641         -0.1038     1.4121    0.0331
# LC_SOCIAL        0.1061        0.1116         -0.0452     0.7637    0.0774
# LC_SYSTEM        0.4659        0.4432          0.0976     0.7668    0.0727
# UT_INFO          0.0558        0.0604         -0.0903     1.0990    0.0510
# UT_SOCIAL        0.1848        0.1652          0.0856     1.3100    0.0519
# UT_SYSTEM        0.2950        0.3029         -0.0340     1.0055    0.0462
# DUT_HOME         0.0862        0.1465         -0.2110     0.7424    0.0664
#           eCDF Max Std. Pair Dist.
# LC_INFO     0.1818          0.5709
# LC_SOCIAL   0.1818          0.4969
# LC_SYSTEM   0.1818          0.4393
# UT_INFO     0.1818          0.8060
# UT_SOCIAL   0.1818          0.6361
# UT_SYSTEM   0.1818          0.4784
# DUT_HOME    0.1818          0.2110
#
# Sample Sizes:
#           Control Treated
# All           446      11
# Matched        11      11
# Unmatched     435       0
# Discarded       0       0
#
#
# $P3$result.UT_WORK$mahalanobis$m.max_smd
# [1] 0.2109721
#
# $P3$result.UT_WORK$mahalanobis$m.treated
# [1] 11
#
# $P3$result.UT_WORK$mahalanobis$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.59530    0.11909  4.9987 6.894e-05 ***
# treat        0.23368    0.16089  1.4524    0.1619
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $P3$result.UT_WORK$cem
# $P3$result.UT_WORK$cem$n_error
# [1] 0

# %%
#OVERALL APP USAGE
csv = "P4.csv"
out = list()
out$pid = strsplit(csv, split=".csv")[[1]]
prepared = prepareData(df,FALSE)
out$removed = prepared$removed
out$sig_corr = sigCorr(prepared$df, "DUT_SEDENTARY")

idx = match(out$removed, all_app_usage)
idx = idx[!is.na(idx)]
if(length(idx) > 0){
    left = all_app_usage[-idx]
}else{
    left = all_app_usage
}
for(elem in left){
    out[[paste("result",elem,sep=".")]] = individual(elem, "DUT_SEDENTARY", prepared$df, 10)
}
# Out:
# Warning message in max(abs(m.balance$sum.matched[-1, "Std. Mean Diff."])):
# “no non-missing arguments to max; returning -Inf”
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#
# Calculating L1 profile for the raw data...
#
#
# Executing 10 different random CEM solutions
#   |                                                                      |   0%
# Using 'treat'='1' as baseline group
#   |========                                                              |  11%
# Using 'treat'='1' as baseline group
#   |================                                                      |  22%
# Using 'treat'='1' as baseline group
#   |=======================                                               |  33%
# Using 'treat'='1' as baseline group
#   |===============================                                       |  44%
# Using 'treat'='1' as baseline group
#   |=======================================                               |  56%
# Using 'treat'='1' as baseline group
#   |===============================================                       |  67%
# Using 'treat'='1' as baseline group
#   |======================================================                |  78%
# Using 'treat'='1' as baseline group
#   |==============================================================        |  89%
# Using 'treat'='1' as baseline group
#   |======================================================================| 100%
# Using 'treat'='1' as baseline group
#
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group
#
# Using 'treat'='1' as baseline group

# %%
print(out)
# Out:
# $pid
# [1] "P4"
#
# $removed
# character(0)
#
# $sig_corr
# [1] "LC_ALL"   "DUT_HOME"
#
# $result.LC_ALL
# $result.LC_ALL$formula
# [1] "treat ~ DUT_HOME"
#
# $result.LC_ALL$ps.nearest
# $result.LC_ALL$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 270 (matched)
#  - target estimand: ATT
#  - covariates: DUT_HOME
#
# $result.LC_ALL$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance        0.3180        0.3178          0.0036     0.9942     0.002
# DUT_HOME        0.1891        0.1905         -0.0037     0.9932     0.002
#          eCDF Max Std. Pair Dist.
# distance   0.0074          0.0059
# DUT_HOME   0.0074          0.0059
#
# Sample Sizes:
#           Control Treated
# All           322     135
# Matched       135     135
# Unmatched     187       0
# Discarded       0       0
#
#
# $result.LC_ALL$ps.nearest$m.max_smd
# [1] 0.003709731
#
# $result.LC_ALL$ps.nearest$m.treated
# [1] 135
#
# $result.LC_ALL$ps.nearest$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.891444   0.021247 41.9557 < 2.2e-16 ***
# treat       -0.141660   0.034947 -4.0536 6.614e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $result.LC_ALL$ps.full
# $result.LC_ALL$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: DUT_HOME
#
# $result.LC_ALL$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance        0.3180        0.3180          0.0006     1.0048    0.0031
# DUT_HOME        0.1891        0.1891         -0.0002     1.0051    0.0031
#          eCDF Max Std. Pair Dist.
# distance   0.0074          0.0104
# DUT_HOME   0.0074          0.0101
#
# Sample Sizes:
#               Control Treated
# All            322.       135
# Matched (ESS)  140.17     135
# Matched        322.       135
# Unmatched        0.         0
# Discarded        0.         0
#
#
# $result.LC_ALL$ps.full$m.max_smd
# [1] 0.000161313
#
# $result.LC_ALL$ps.full$m.treated
# [1] 135
#
# $result.LC_ALL$ps.full$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.878086   0.021430 40.9756 < 2.2e-16 ***
# treat       -0.128303   0.033441 -3.8367 0.0001423 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $result.LC_ALL$mahalanobis
# $result.LC_ALL$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 270 (matched)
#  - target estimand: ATT
#  - covariates: DUT_HOME
#
# $result.LC_ALL$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# DUT_HOME        0.1891        0.1893         -0.0005     0.9915     0.002
#          eCDF Max Std. Pair Dist.
# DUT_HOME   0.0074          0.0069
#
# Sample Sizes:
#           Control Treated
# All           322     135
# Matched       135     135
# Unmatched     187       0
# Discarded       0       0
#
#
# $result.LC_ALL$mahalanobis$m.max_smd
# [1] -Inf
#
# $result.LC_ALL$mahalanobis$m.treated
# [1] 135
#
# $result.LC_ALL$mahalanobis$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  0.891444   0.021247  41.956 < 2.2e-16 ***
# treat       -0.141660   0.035628  -3.976 9.019e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $result.LC_ALL$cem
# $result.LC_ALL$cem$n_error
# [1] 0
#
#
#
# $result.UT_ALL
# $result.UT_ALL$formula
# [1] "treat ~ LC_ALL + DUT_HOME"
#
# $result.UT_ALL$ps.nearest
# $result.UT_ALL$ps.nearest$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 264 (matched)
#  - target estimand: ATT
#  - covariates: LC_ALL, DUT_HOME
#
# $result.UT_ALL$ps.nearest$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance        0.4862        0.3389          0.5102     2.8315    0.1343
# LC_ALL          0.1967        0.0914          0.5169     4.2960    0.1553
# DUT_HOME        0.3997        0.5369         -0.2895     0.9071    0.1311
#          eCDF Max Std. Pair Dist.
# distance   0.2879          0.5110
# LC_ALL     0.2727          0.5664
# DUT_HOME   0.1818          0.7284
#
# Sample Sizes:
#           Control Treated
# All           325     132
# Matched       132     132
# Unmatched     193       0
# Discarded       0       0
#
#
# $result.UT_ALL$ps.nearest$m.max_smd
# [1] 0.5168567
#
# $result.UT_ALL$ps.nearest$m.treated
# [1] 132
#
# $result.UT_ALL$ps.nearest$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.866961   0.023272 37.2529   <2e-16 ***
# treat       -0.018487   0.035005 -0.5281   0.5979
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $result.UT_ALL$ps.full
# $result.UT_ALL$ps.full$m.out
# A matchit object
#  - method: Optimal full matching
#  - distance: Propensity score
#              - estimated with logistic regression
#  - number of obs.: 457 (original), 457 (matched)
#  - target estimand: ATT
#  - covariates: LC_ALL, DUT_HOME
#
# $result.UT_ALL$ps.full$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# distance        0.4862        0.4838          0.0083     0.9781    0.0157
# LC_ALL          0.1967        0.1998         -0.0151     1.5571    0.0521
# DUT_HOME        0.3997        0.2538          0.3078     1.1467    0.1403
#          eCDF Max Std. Pair Dist.
# distance   0.1515          0.0228
# LC_ALL     0.1566          0.1939
# DUT_HOME   0.1875          0.4925
#
# Sample Sizes:
#               Control Treated
# All             325.      132
# Matched (ESS)    22.1     132
# Matched         325.      132
# Unmatched         0.        0
# Discarded         0.        0
#
#
# $result.UT_ALL$ps.full$m.max_smd
# [1] 0.3077703
#
# $result.UT_ALL$ps.full$m.treated
# [1] 132
#
# $result.UT_ALL$ps.full$m.att
#
# t test of coefficients:
#
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.793294   0.081314  9.7559   <2e-16 ***
# treat       0.055180   0.076478  0.7215    0.471
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $result.UT_ALL$mahalanobis
# $result.UT_ALL$mahalanobis$m.out
# A matchit object
#  - method: 1:1 nearest neighbor matching without replacement
#  - distance: Mahalanobis
#  - number of obs.: 457 (original), 264 (matched)
#  - target estimand: ATT
#  - covariates: LC_ALL, DUT_HOME
#
# $result.UT_ALL$mahalanobis$m.balance
#
# Call:
# matchit(formula = formula, data = df, method = if (distance ==
#     "PS") method else "nearest", distance = if (distance == "PS") "glm" else "mahalanobis")
#
# Summary of Balance for Matched Data:
#          Means Treated Means Control Std. Mean Diff. Var. Ratio eCDF Mean
# LC_ALL          0.1967        0.1029          0.4604     4.7758    0.1345
# DUT_HOME        0.3997        0.4222         -0.0476     0.9450    0.0221
#          eCDF Max Std. Pair Dist.
# LC_ALL     0.2652          0.4681
# DUT_HOME   0.0530          0.0844
#
# Sample Sizes:
#           Control Treated
# All           325     132
# Matched       132     132
# Unmatched     193       0
# Discarded       0       0
#
#
# $result.UT_ALL$mahalanobis$m.max_smd
# [1] 0.04758963
#
# $result.UT_ALL$mahalanobis$m.treated
# [1] 132
#
# $result.UT_ALL$mahalanobis$m.att
#
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.8413389  0.0250697 33.5599   <2e-16 ***
# treat       0.0071345  0.0310016  0.2301   0.8182
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#
#
# $result.UT_ALL$cem
# $result.UT_ALL$cem$m.out
#            G0  G1
# All       325 132
# Matched   325 121
# Unmatched   0  11
#
#
# $result.UT_ALL$cem$m.balance
# Balance Measures
#             Type Diff.Un Diff.Adj
# LC_ALL   Contin.  0.7180   0.5179
# DUT_HOME Contin.  0.2505  -0.0032
#
# Sample sizes
#                      Control Treated
# All                   325.       132
# Matched (ESS)         268.96     115
# Matched (Unweighted)  318.       115
# Unmatched               7.        17
#
# $result.UT_ALL$cem$m.att
#
#            G0  G1
# All       325 132
# Matched   318 115
# Unmatched   7  17
#
# Linear regression model on CEM matched data:
#
# SATT point estimate: -0.027990 (p.value=0.300262)
# 95% conf. interval: [-0.080887, 0.024906]
#
#
# $result.UT_ALL$cem$m.treated
# [1] 121
#
# $result.UT_ALL$cem$n_error
# [1] 0
